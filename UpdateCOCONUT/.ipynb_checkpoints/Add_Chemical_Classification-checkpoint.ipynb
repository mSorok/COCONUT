# %%
import pyclassyfire.client

# %%
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import json

from time import sleep

client = MongoClient("localhost:27017")
db = client['COCONUT2020-07']

# %%
classification_dic ={}

df = pd.read_csv("classification/COCONUT4MetFrag_ClassyFied.tsv",sep="\t")

# %%
df
# Out:
#         Unnamed: 0  Identifier MolecularFormula  \
# 0                0  CNP0000001         C19H22O8
# 1                1  CNP0000002         C25H20O6
# 2                2  CNP0000003       C25H43NO10
# 3                3  CNP0000004         C25H36O5
# 4                4  CNP0000005          C10H16S
# ...            ...         ...              ...
# 412898      412898  CNP0412899         C20H28O5
# 412899      412899  CNP0412900     [C51H76NO4]+
# 412900      412900  CNP0412901       C50H81NO16
# 412901      412901  CNP0412902     C35H48N7O19P
# 412902      412902  CNP0412903        C26H32O11
#
#                                                    SMILES  \
# 0       O=C1OC2=CC(=CC(OC3OC(CO)C(O)C(O)C3O)=C2C4=C1CC...
# 1       O=C1C=C(OC=2C1=C(O)C=C(O)C2C(C=3C=CC=CC3)CC(=O...
# 2       O=C(NC1OCOC2C1OC(CC(OC)CO)C(C)(C)C2OC)C(O)C3(O...
# 3       O=C(OC1C(=C)C2CCC3(O)C4(C)CCCC(C(=O)O)(C)C4CCC...
# 4                                    S=C1CC2CCC1(C)C2(C)C
# ...                                                   ...
# 412898   O=C(OC1CC(=CC(O)CC(=CC2OC(=O)C(C)C21)C)C)C(=CC)C
# 412899  OC1CC2C3CCC4C(C[NH+]5CC(CCCC=6C=CC=CC6)CCC5C4(...
# 412900  O=C(O)C12C3=C(CCC2(C)C(CC1)C(C)CCC(=C)C(C)(C)C...
# 412901  O=C(O)CCC(OP(=O)(O)OCC1OC(OCC(O)C(O)C(O)CC2=CC...
# 412902  O=C(OC1C(=O)OC2CC3C(=C(O)C(=O)CC3(C)C4C(O)C(O)...
#
#                                                     InChI  \
# 0       InChI=1S/C19H22O8/c1-8-5-11-14(9-3-2-4-10(9)18...
# 1       InChI=1S/C25H20O6/c1-30-22(29)12-17(15-8-4-2-5...
# 2       InChI=1S/C25H43NO10/c1-13-10-25(32-8,36-15(3)1...
# 3       InChI=1S/C25H36O5/c1-15(2)13-19(26)30-20-16(3)...
# 4       InChI=1S/C10H16S/c1-9(2)7-4-5-10(9,3)8(11)6-7/...
# ...                                                   ...
# 412898  InChI=1S/C20H28O5/c1-6-13(4)19(22)24-16-9-11(2...
# 412899  InChI=1S/C51H75NO4/c1-49-33-51(24-23-36(30-51)...
# 412900  InChI=1S/C50H81NO16/c1-24(11-12-25(2)46(4,5)6)...
# 412901  InChI=1S/C35H48N7O19P/c1-14(25-15(2)38-30-26(4...
# 412902  InChI=1S/C26H32O11/c1-10(2)6-15(28)37-18-20-25...
#
#                            InChIKey CompoundName             SIK  \
# 0       AAAACIDXVXFWLZ-UHFFFAOYSA-N   CNP0000001  AAAACIDXVXFWLZ
# 1       AAAAWQOPBUPWEV-UHFFFAOYSA-N   CNP0000002  AAAAWQOPBUPWEV
# 2       AAABMNXUOFPYQK-UHFFFAOYSA-N   CNP0000003  AAABMNXUOFPYQK
# 3       AAACJXBPRRVSAV-UHFFFAOYSA-N   CNP0000004  AAACJXBPRRVSAV
# 4       AAADKYXUTOBAGS-UHFFFAOYSA-N   CNP0000005  AAADKYXUTOBAGS
# ...                             ...          ...             ...
# 412898  ZZZSTRSHESHLMT-UHFFFAOYSA-N   CNP0412899  ZZZSTRSHESHLMT
# 412899  ZZZUHNOMGBMETN-UHFFFAOYSA-O   CNP0412900  ZZZUHNOMGBMETN
# 412900  ZZZXFLFNSDOOJJ-UHFFFAOYSA-N   CNP0412901  ZZZXFLFNSDOOJJ
# 412901  ZZZXRXDSTUEPEK-UHFFFAOYSA-N   CNP0412902  ZZZXRXDSTUEPEK
# 412902  ZZZYHIMVKOHVIH-UHFFFAOYSA-N   CNP0412903  ZZZYHIMVKOHVIH
#
#               inchikey shortikSanitized       kingdom.name  \
# 0       AAAACIDXVXFWLZ   AAAACIDXVXFWLZ  Organic compounds
# 1       AAAAWQOPBUPWEV   AAAAWQOPBUPWEV  Organic compounds
# 2       AAABMNXUOFPYQK   AAABMNXUOFPYQK  Organic compounds
# 3       AAACJXBPRRVSAV   AAACJXBPRRVSAV  Organic compounds
# 4       AAADKYXUTOBAGS   AAADKYXUTOBAGS  Organic compounds
# ...                ...              ...                ...
# 412898  ZZZSTRSHESHLMT   ZZZSTRSHESHLMT  Organic compounds
# 412899  ZZZUHNOMGBMETN   ZZZUHNOMGBMETN  Organic compounds
# 412900  ZZZXFLFNSDOOJJ   ZZZXFLFNSDOOJJ  Organic compounds
# 412901  ZZZXRXDSTUEPEK   ZZZXRXDSTUEPEK  Organic compounds
# 412902  ZZZYHIMVKOHVIH   ZZZYHIMVKOHVIH  Organic compounds
#
#                          superclass.name                        class.name  \
# 0               Organic oxygen compounds            Organooxygen compounds
# 1       Phenylpropanoids and polyketides                  Diarylheptanoids
# 2           Organoheterocyclic compounds                     Pyranodioxins
# 3        Lipids and lipid-like molecules                     Prenol lipids
# 4        Lipids and lipid-like molecules                     Prenol lipids
# ...                                  ...                               ...
# 412898   Lipids and lipid-like molecules                     Prenol lipids
# 412899   Lipids and lipid-like molecules  Steroids and steroid derivatives
# 412900   Lipids and lipid-like molecules                     Prenol lipids
# 412901          Organic oxygen compounds            Organooxygen compounds
# 412902   Lipids and lipid-like molecules                     Prenol lipids
#
#                      direct_parent.name  \
# 0                   Phenolic glycosides
# 1               Linear diarylheptanoids
# 2                         Pyranodioxins
# 3                  Kaurane diterpenoids
# 4               Bicyclic monoterpenoids
# ...                                 ...
# 412898  Germacranolides and derivatives
# 412899       Cerveratrum-type alkaloids
# 412900                    Triterpenoids
# 412901               Pentose phosphates
# 412902                      Quassinoids
#
#                                     subclass.name
# 0       Carbohydrates and carbohydrate conjugates
# 1                         Linear diarylheptanoids
# 2                                             NaN
# 3                                    Diterpenoids
# 4                                  Monoterpenoids
# ...                                           ...
# 412898                           Terpene lactones
# 412899                        Steroidal alkaloids
# 412900                              Triterpenoids
# 412901  Carbohydrates and carbohydrate conjugates
# 412902                           Terpene lactones
#
# [412903 rows x 15 columns]

# %%
# add classification -> need to define which level

# for NPs where there is no classification available -> use the classifyre API (python)

# %%
classification_dic = {}


for index, row in df.iterrows():
    inchikey = row['InChIKey']
    superclass = row['superclass.name']
    cclass = row['class.name']
    subclass = row['subclass.name']
    direct_parent = row['direct_parent.name']
    
    classification_dic[inchikey] = [superclass, cclass, subclass, direct_parent]

# %%
collection = db.uniqueNaturalProduct.aggregate( [ {'$project': { '_id':0, 'coconut_id':1, 'inchikey':1, "inchi":1}} ] )

allnp = pd.DataFrame(list(collection))

# %%
for index, row in allnp.iterrows():
    coconut_id = row['coconut_id']
    inchikey = row["inchikey"]
    inchi = row["inchi"]
    
    if inchikey in classification_dic.keys():
        db.uniqueNaturalProduct.update_one({'coconut_id': coconut_id}, {"$set": {
            "chemicalSuperClass":classification_dic[inchikey][0], "chemicalClass":classification_dic[inchikey][1],
            "chemicalSubClass":classification_dic[inchikey][2], "directParentClassification":classification_dic[inchikey][3]}})
    else:
        #need to search with classyfire
        try:
            #r = pyclassyfire.client.get_entity(inchikey, "json")
            
            qid = pyclassyfire.client.structure_query(inchi)
            r = pyclassyfire.client.get_results(qid, 'json')
            
            if len(r.keys())>0:
                cclass = ""
                direct_parent=''
                inchikey = ""
                superclass = ""
                subclass = ""

                if "class" in r:
                    cclass = r["class"]["name"]

                if "direct_parent" in r:
                    direct_parent = cclass = r["direct_parent"]["name"]


                if "inchikey" in r:
                    inchikey = r["inchikey"].split("=")[1] #"InChIKey=AAAACIDXVXFWLZ-UHFFFAOYSA-N"

                if "superclass" in r:
                    superclass = r["superclass"]["name"]

                if "subclass" in r:
                    subclass = r["subclass"]["name"]
                    
                db.uniqueNaturalProduct.update_one({'coconut_id': coconut_id}, {"$set": {
                    "chemicalSuperClass":superclass, "chemicalClass":cclass,
                    "chemicalSubClass":subclass, "directParentClassification":direct_parent}})
                
            else:
                db.uniqueNaturalProduct.update_one({'coconut_id': coconut_id}, {"$set": {
                    "chemicalSuperClass":"", "chemicalClass":"",
                    "chemicalSubClass":"", "directParentClassification":""}})
        except Exception as e:
            print("Nothing found in Classifire for "+inchikey)
            
            db.uniqueNaturalProduct.update_one({'coconut_id': coconut_id}, {"$set": {
            "chemicalSuperClass":"", "chemicalClass":"",
            "chemicalSubClass":"", "directParentClassification":""}})
# Out:
# Nothing found in Classifire for AABGBLUUWZOOHU-UHFFFAOYSA-N
# Nothing found in Classifire for AACFPJSJOWQNBN-UHFFFAOYSA-N
# Nothing found in Classifire for AADYWCBPJZAJNU-UHFFFAOYSA-N
# Nothing found in Classifire for AAECGPYNABRRCD-UHFFFAOYSA-N
# Nothing found in Classifire for AAFBEHCDVQXPKK-UHFFFAOYSA-N
# Nothing found in Classifire for AAFUUKPTSPVXJH-UHFFFAOYSA-N
# Nothing found in Classifire for AAGDXZPLAMIJGH-UHFFFAOYSA-N
# Nothing found in Classifire for AAHWXJUQSQBIIS-UHFFFAOYSA-N
# Nothing found in Classifire for AAIIJIOWYALNCC-UHFFFAOYSA-N
# Nothing found in Classifire for AAJAPPYEUBJOGG-UHFFFAOYSA-N
# Nothing found in Classifire for AAJSOHFSWPEFNN-UHFFFAOYSA-O
# Nothing found in Classifire for AAMXZVUGBRFIKW-UHFFFAOYSA-N
# Nothing found in Classifire for AANUHWSTTDENRF-UHFFFAOYSA-O
# Nothing found in Classifire for AAOOVFKOTYJAEJ-UHFFFAOYSA-N
# Nothing found in Classifire for AAPDIMVMXZOXGT-UHFFFAOYSA-N
# Nothing found in Classifire for AAPDYUDAVPNPER-UHFFFAOYSA-N
# Nothing found in Classifire for AAPJMRBUVBWSLD-UHFFFAOYSA-N
# Nothing found in Classifire for AAQRZBVHHHZEHA-UHFFFAOYSA-N
# Nothing found in Classifire for AAQVTSDGGKTPTI-UHFFFAOYSA-N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7188b826cc87> in <module>
#      11         #need to search with classyfire
#      12         try:
# ---> 13             r = pyclassyfire.client.get_entity(inchikey, "json")
#      14
#      15             if len(r.keys())>0:
#
# /Applications/anaconda3/lib/python3.7/site-packages/pyclassyfire-0.1-py3.7.egg/pyclassyfire/client.py in get_entity(inchikey, return_format)
#     104     r = requests.get('%s/entities/%s.%s' % (url, inchikey, return_format),
#     105                      headers={
# --> 106                          "Content-Type": "application/%s" % return_format})
#     107     r.raise_for_status()
#     108     return r.text
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /Applications/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /Applications/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
